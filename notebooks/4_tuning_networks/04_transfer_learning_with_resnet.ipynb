# %% [markdown]
# <td>
# <a href="https://colab.research.google.com/github/raoulg/MADS-MachineLearning-course/blob/master/notebooks/4_tuning_networks/04_transfer_learning_with_resnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# </td>

# %%
import os
# Check if the notebook is running on Google Colab
colab = False
if 'COLAB_GPU' in os.environ:
    colab = True
    # Running on Google Colab; install loguru
    # !pip install mads_datasets mltrainer loguru
else:
    # Not running on Google Colab; you might be on a local setup
    print("Not running on Google Colab. Ensure dependencies are installed as needed.")
# Out:
# Not running on Google Colab. Ensure dependencies are installed as needed.

# %%
from pathlib import Path
from loguru import logger
import torch
import matplotlib.pyplot as plt

# %% [markdown]
# Let's revisit the flowers dataset from the first lesson

# %%
from mads_datasets import DatasetFactoryProvider, DatasetType

flowersfactory = DatasetFactoryProvider.create_factory(DatasetType.FLOWERS)
streamers = flowersfactory.create_datastreamer(batchsize=32)
# Out:
# 2025-02-16 11:09:10.310 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /home/sarmad/.cache/mads_datasets/flowers

# %% [markdown]
# We have just about 3000 images. To get more out of our data, we will use a technique called 'data augmentation'. When an image if flipped, or cropped, we get a different image, preventing the model to overfit on the quirks of this small dataset. We will also normalize the images to the mean and standard deviation used when training resnet; this is not strictly necessary, but should make it a bit easier for the model to work with our images.

# %%
from torchvision import transforms
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %% [markdown]
# Because we want to crop the images, lets make our images during preprocessing a bit bigger, so we actually have something to crop:

# %%
flowersfactory.settings
# Out:
# dataset_url: https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# filename: flowers.tgz
# name: flowers
# unzip: True
# formats: [<FileTypes.JPG: '.jpg'>]
# digest: 6f87fb78e9cc9ab41eff2015b380011d
# trainfrac: 0.8
# img_size: (224, 224)

# %%
flowersfactory.settings.img_size = (500, 500)

# %% [markdown]
# With this modification of the settings, we can create the dataset.
# We can see our images are actually 500x500 pixels now.
#
# The transformations are just a function; we can input the img and get a transformed image out. Let try that,
# and visualise the result:
#
# PS: if you dont have enough RAM on colab (eg 12GB), the cell below might crash your notebook (because it recreates the dataset);
# the first cell in this notebook has set the value of 'colab' to True if you are on colab, to avoid this issue.

# %%
if not colab:
    datasets = flowersfactory.create_dataset()
    traindataset = datasets["train"]
    img, lab = traindataset[0]
    logger.info(f"original shape: {img.shape}")
    # original shape: torch.Size([3, 500, 500])
    transformed_img = data_transforms["train"](img)
    logger.info(f"transformed shape: {transformed_img.shape}")
    # transformed shape: torch.Size([3, 224, 224])

    fig, ax = plt.subplots(1, 2)
    ax[0].imshow(img.numpy().transpose(1, 2, 0))
    ax[1].imshow(transformed_img.numpy().transpose(1, 2, 0))
# Out:
# 2025-02-16 11:09:22.024 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /home/sarmad/.cache/mads_datasets/flowers
# 2025-02-16 11:09:42.314 | INFO     | __main__:<module>:5 - original shape: torch.Size([3, 500, 500])
# 2025-02-16 11:09:42.316 | INFO     | __main__:<module>:8 - transformed shape: torch.Size([3, 224, 224])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.8044444..2.3932312].

# %% [markdown]
# Instead of using the BasePreprocessor, we will squeeze in the transformer. Lets make that:

# %%
class AugmentPreprocessor():
    def __init__(self, transform):
        self.transform = transform
    def __call__(self, batch: list[tuple]) -> tuple[torch.Tensor, torch.Tensor]:
        X, y = zip(*batch)
        X = [self.transform(x) for x in X]
        return torch.stack(X), torch.stack(y)

# %% [markdown]
# Now we can create an separate preprocessor for train and validation:

# %%
trainprocessor= AugmentPreprocessor(data_transforms["train"])
validprocessor = AugmentPreprocessor(data_transforms["val"])

# %% [markdown]
# And add that as the preprocessor for train and validation streamers. We do it like this because by default we can only provide a single preprocessor for both training and validation.

# %%
train = streamers["train"]
valid = streamers["valid"]
train.preprocessor = trainprocessor
valid.preprocessor = validprocessor
trainstreamer = train.stream()
validstreamer = valid.stream()

# %% [markdown]
# Let's confirm this works:

# %%
X, y = next(trainstreamer)
X.shape, y.shape
# Out:
# (torch.Size([32, 3, 224, 224]), torch.Size([32]))

# %% [markdown]
# And lets visualise a random batch of images

# %%
import matplotlib.pyplot as plt
import numpy as np
img = X.permute(0, 2, 3, 1).numpy()
mean = np.array([0.485, 0.456, 0.406])
std = np.array([0.229, 0.224, 0.225])
img = std * img + mean
img = np.clip(img, 0, 1)
fig, axs = plt.subplots(3, 3, figsize=(10,10))
axs = axs.ravel()
for i in range(9):
    axs[i].imshow(img[i])

# %% [markdown]
# Instead of building our own resnet, we will just download a pretrained version. This saves us many hours of training.

# %%
import torchvision
from torchvision.models import resnet18, ResNet18_Weights
resnet = torchvision.models.resnet18(weights=ResNet18_Weights.DEFAULT)

# %%
ResNet18_Weights.DEFAULT
# Out:
# ResNet18_Weights.IMAGENET1K_V1

# %%
yhat = resnet(X)
yhat.shape
# Out:
# torch.Size([32, 1000])

# %% [markdown]
# However, the resnet is trained for 1000 classes. We have just 5...
#
# We will swap the last layer and retrain the model.
#
# First, we freeze all pretrained layers:

# %%
for name, param in resnet.named_parameters():
    param.requires_grad = False

# %% [markdown]
# If you study the resnet implementation on [github](https://github.com/pytorch/vision/blob/main/torchvision/models/resnet.py#L206) you can see that the last layer is named `.fc`, like this:
#
# ```
#  self.fc = nn.Linear(512 * block.expansion, num_classes)
#  ```
#
# This is a Linear layer, mapping from 512 * block.expansion to num_classes.
#
#
# so we will swap that for our own. To do so we need to figure out how many features go into the .fc layer.
# We can retrieve the incoming amount of features for the current `.fc` with `.in_features`

# %%
print(type(resnet.fc))
in_features = resnet.fc.in_features
in_features
# Out:
# <class 'torch.nn.modules.linear.Linear'>
# 512

# %% [markdown]
# Let's swap that layer with a minimal network. Sometimes just a linear layer is enough, sometimes you want to add two layers and some dropout.
# Play around to see the difference!

# %%
import torch.nn as nn

resnet.fc = nn.Sequential(
    nn.Linear(in_features, 5)
    # nn.Linear(in_features, 128), nn.ReLU(), nn.Dropout(0.1), nn.Linear(128, 5)
)

# %%
yhat = resnet(X)
yhat.shape
# Out:
# torch.Size([32, 5])

# %% [markdown]
# So, we have a fully trained resnet, but we added one layers at the end that transforms everything into 5 classes.
# These layers are random, so we need to train them for some epochs

# %%
from mltrainer import metrics
accuracy = metrics.Accuracy()

# %% [markdown]
# This will take some time to train (about 4 min per epoch), you could scale down to amount of trainsteps to speed things up.
#
# You will start with a fairly high learning rate (0.01), and if the learning stops, after patience epochs the learning rate gets halved.

# %%
len(train), len(valid)
# Out:
# (91, 22)

# %%
if torch.backends.mps.is_available() and torch.backends.mps.is_built():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = "cpu"
    logger.warning("This model will take 15-20 minutes on CPU. Consider using accelaration, eg with google colab (see button on top of the page)")
logger.info(f"Using {device}")
# Out:
# 2025-02-16 11:09:45.208 | INFO     | __main__:<module>:8 - Using cuda

# %% [markdown]
# We are going to use SGD as optimizer and a stepLR as scheduler.

# %%
from torch import optim
optimizer = optim.SGD
scheduler = optim.lr_scheduler.StepLR

# %%
from mltrainer import Trainer, TrainerSettings, ReportTypes

settings = TrainerSettings(
    epochs=30,
    metrics=[accuracy],
    logdir="modellogs/flowers",
    train_steps=len(train),
    valid_steps=len(valid),
    reporttypes=[ReportTypes.TENSORBOARD],
    optimizer_kwargs= {'lr': 0.1, 'weight_decay': 1e-05, 'momentum': 0.9},
    scheduler_kwargs= {'step_size' : 10, 'gamma' : 0.1},
    earlystop_kwargs= None,
)
settings
# Out:
# epochs: 30
# metrics: [Accuracy]
# logdir: modellogs/flowers
# train_steps: 91
# valid_steps: 22
# reporttypes: [<ReportTypes.TENSORBOARD: 2>]
# optimizer_kwargs: {'lr': 0.1, 'weight_decay': 1e-05, 'momentum': 0.9}
# scheduler_kwargs: {'step_size': 10, 'gamma': 0.1}
# earlystop_kwargs: None

# %%
trainer = Trainer(
    model=resnet,
    settings=settings,
    loss_fn=nn.CrossEntropyLoss(),
    optimizer=optimizer,
    traindataloader=trainstreamer,
    validdataloader=validstreamer,
    scheduler=scheduler,
    device='cpu'
    )
# Out:
# 2025-02-16 11:09:45.237 | INFO     | mltrainer.trainer:dir_add_timestamp:29 - Logging to modellogs/flowers/20250216-110945

# %%
# note: this will be very slow without acceleration!
trainer.loop()
# Out:
# 100%|██████████| 91/91 [00:43<00:00,  2.10it/s]
# 2025-02-16 11:10:39.048 | INFO     | mltrainer.trainer:report:191 - Epoch 0 train 4.6465 test 3.1176 metric ['0.8196']
# 100%|██████████| 91/91 [00:41<00:00,  2.22it/s]
# 2025-02-16 11:11:27.481 | INFO     | mltrainer.trainer:report:191 - Epoch 1 train 3.3685 test 2.3338 metric ['0.8821']
# 100%|██████████| 91/91 [00:38<00:00,  2.39it/s]
# 2025-02-16 11:12:13.223 | INFO     | mltrainer.trainer:report:191 - Epoch 2 train 3.4419 test 4.7025 metric ['0.8082']
# 100%|██████████| 91/91 [00:36<00:00,  2.49it/s]
# 2025-02-16 11:12:57.804 | INFO     | mltrainer.trainer:report:191 - Epoch 3 train 3.7828 test 2.6635 metric ['0.8707']
# 100%|██████████| 91/91 [01:17<00:00,  1.18it/s]
# 2025-02-16 11:14:30.519 | INFO     | mltrainer.trainer:report:191 - Epoch 4 train 2.8204 test 2.7135 metric ['0.8594']
# 100%|██████████| 91/91 [01:02<00:00,  1.45it/s]
# 2025-02-16 11:15:47.409 | INFO     | mltrainer.trainer:report:191 - Epoch 5 train 2.5115 test 2.5073 metric ['0.8807']
# 100%|██████████| 91/91 [01:03<00:00,  1.44it/s]
# 2025-02-16 11:17:04.793 | INFO     | mltrainer.trainer:report:191 - Epoch 6 train 2.3310 test 2.1589 metric ['0.8920']
# 100%|██████████| 91/91 [01:04<00:00,  1.40it/s]
# 2025-02-16 11:18:23.466 | INFO     | mltrainer.trainer:report:191 - Epoch 7 train 3.5892 test 2.2557 metric ['0.8906']
# 100%|██████████| 91/91 [01:02<00:00,  1.47it/s]
# 2025-02-16 11:19:40.339 | INFO     | mltrainer.trainer:report:191 - Epoch 8 train 3.2504 test 2.2376 metric ['0.8949']
# 100%|██████████| 91/91 [01:01<00:00,  1.49it/s]
# 2025-02-16 11:20:55.003 | INFO     | mltrainer.trainer:report:191 - Epoch 9 train 2.8361 test 2.6878 metric ['0.8750']
# 100%|██████████| 91/91 [01:00<00:00,  1.51it/s]
# 2025-02-16 11:22:08.622 | INFO     | mltrainer.trainer:report:191 - Epoch 10 train 1.8472 test 1.9912 metric ['0.9062']
# 100%|██████████| 91/91 [00:59<00:00,  1.52it/s]
# 2025-02-16 11:23:22.612 | INFO     | mltrainer.trainer:report:191 - Epoch 11 train 1.5417 test 1.9316 metric ['0.9006']
# 100%|██████████| 91/91 [01:00<00:00,  1.51it/s]
# 2025-02-16 11:24:35.987 | INFO     | mltrainer.trainer:report:191 - Epoch 12 train 1.6617 test 1.6750 metric ['0.9162']
# 100%|██████████| 91/91 [00:58<00:00,  1.56it/s]
# 2025-02-16 11:25:41.622 | INFO     | mltrainer.trainer:report:191 - Epoch 13 train 1.5202 test 1.7573 metric ['0.9077']
# 100%|██████████| 91/91 [00:33<00:00,  2.75it/s]
# 2025-02-16 11:26:22.032 | INFO     | mltrainer.trainer:report:191 - Epoch 14 train 1.5125 test 1.7181 metric ['0.9048']
# 100%|██████████| 91/91 [00:33<00:00,  2.74it/s]
# 2025-02-16 11:27:02.378 | INFO     | mltrainer.trainer:report:191 - Epoch 15 train 1.4214 test 1.7166 metric ['0.9105']
# 100%|██████████| 91/91 [00:33<00:00,  2.72it/s]
# 2025-02-16 11:27:43.231 | INFO     | mltrainer.trainer:report:191 - Epoch 16 train 1.3787 test 1.5995 metric ['0.9077']
# 100%|██████████| 91/91 [00:33<00:00,  2.72it/s]
# 2025-02-16 11:28:23.849 | INFO     | mltrainer.trainer:report:191 - Epoch 17 train 1.4984 test 1.5801 metric ['0.9077']
# 100%|██████████| 91/91 [00:33<00:00,  2.75it/s]
# 2025-02-16 11:29:04.316 | INFO     | mltrainer.trainer:report:191 - Epoch 18 train 1.3991 test 1.4004 metric ['0.9148']
# 100%|██████████| 91/91 [00:33<00:00,  2.72it/s]
# 2025-02-16 11:29:44.941 | INFO     | mltrainer.trainer:report:191 - Epoch 19 train 1.3761 test 1.5486 metric ['0.9091']
# 100%|██████████| 91/91 [00:32<00:00,  2.76it/s]
# 2025-02-16 11:30:25.110 | INFO     | mltrainer.trainer:report:191 - Epoch 20 train 1.3464 test 1.5634 metric ['0.9134']
# 100%|██████████| 91/91 [00:33<00:00,  2.75it/s]
# 2025-02-16 11:31:05.372 | INFO     | mltrainer.trainer:report:191 - Epoch 21 train 1.1839 test 1.5188 metric ['0.9105']
# 100%|██████████| 91/91 [00:33<00:00,  2.74it/s]
# 2025-02-16 11:31:45.830 | INFO     | mltrainer.trainer:report:191 - Epoch 22 train 1.2447 test 1.5430 metric ['0.9077']
# 100%|██████████| 91/91 [00:33<00:00,  2.73it/s]
# 2025-02-16 11:32:26.471 | INFO     | mltrainer.trainer:report:191 - Epoch 23 train 1.2611 test 1.4809 metric ['0.9091']
# 100%|██████████| 91/91 [00:33<00:00,  2.74it/s]
# 2025-02-16 11:33:06.847 | INFO     | mltrainer.trainer:report:191 - Epoch 24 train 1.2160 test 1.5605 metric ['0.9077']
# 100%|██████████| 91/91 [00:33<00:00,  2.72it/s]
# 2025-02-16 11:33:47.511 | INFO     | mltrainer.trainer:report:191 - Epoch 25 train 1.1544 test 1.5461 metric ['0.9105']
# 100%|██████████| 91/91 [00:33<00:00,  2.74it/s]
# 2025-02-16 11:34:27.920 | INFO     | mltrainer.trainer:report:191 - Epoch 26 train 1.2007 test 1.5030 metric ['0.9105']
# 100%|██████████| 91/91 [00:32<00:00,  2.76it/s]
# 2025-02-16 11:35:08.217 | INFO     | mltrainer.trainer:report:191 - Epoch 27 train 1.2157 test 1.4919 metric ['0.9105']
# 100%|██████████| 91/91 [00:33<00:00,  2.73it/s]
# 2025-02-16 11:35:48.712 | INFO     | mltrainer.trainer:report:191 - Epoch 28 train 1.0808 test 1.5361 metric ['0.9105']
# 100%|██████████| 91/91 [00:33<00:00,  2.72it/s]
# 2025-02-16 11:36:29.404 | INFO     | mltrainer.trainer:report:191 - Epoch 29 train 1.2699 test 1.5525 metric ['0.9091']
# 100%|██████████| 30/30 [26:44<00:00, 53.47s/it]

# %% [markdown]
# <font color='green'>
#
# **Before we used only single layer at the end of the RESNET. Now, lets test it by adding two `Linear` layers at the very end of the trained Resnet model. Note: it will take some time without gpu acceleration, so consider using local dedicated GPU or use the free GPU provided by the colab.**
#
# Previously, we only used single Linear layer as `nn.Linear(in_features, 5)`, but now we will use two Linear layers in combination with dropout layer to add regularizational layer.
#
# We also initailize the resent model again, because it is already trained previously, so a new instance of the model is necessary to train it again to compare the two models. So, same process we will do of freezing the model.
# </font>

# %%
resnet2 = torchvision.models.resnet18(weights=ResNet18_Weights.DEFAULT)
for name, param in resnet2.named_parameters():
    param.requires_grad = False

# %%
import torch.nn as nn

resnet2.fc = nn.Sequential(
    nn.Linear(in_features, 128), nn.ReLU(), nn.Dropout(0.1), nn.Linear(128, 5)
)

# %%
from mltrainer import Trainer, TrainerSettings, ReportTypes

settings = TrainerSettings(
    epochs=30,
    metrics=[accuracy],
    logdir="modellogs/flowers",
    train_steps=len(train),
    valid_steps=len(valid),
    reporttypes=[ReportTypes.TENSORBOARD],
    optimizer_kwargs= {'lr': 0.001, 'weight_decay': 1e-05, 'momentum': 0.9},
    scheduler_kwargs= {'step_size' : 10, 'gamma' : 0.1},
    earlystop_kwargs= None,
)

trainer = Trainer(
    model=resnet2,      # the new resent instance
    settings=settings,
    loss_fn=nn.CrossEntropyLoss(),
    optimizer=optimizer,
    traindataloader=trainstreamer,
    validdataloader=validstreamer,
    scheduler=scheduler,
    device='cpu',
    )
# Out:
# 2025-02-16 16:47:01.392 | INFO     | mltrainer.trainer:dir_add_timestamp:29 - Logging to modellogs/flowers/20250216-164701

# %%
# taining the new model ...
trainer.loop()
# Out:
# 100%|██████████| 91/91 [00:45<00:00,  1.98it/s]
# 2025-02-16 16:47:58.492 | INFO     | mltrainer.trainer:report:191 - Epoch 0 train 1.3430 test 0.9359 metric ['0.8111']
# 100%|██████████| 91/91 [00:45<00:00,  2.00it/s]
# 2025-02-16 16:48:54.391 | INFO     | mltrainer.trainer:report:191 - Epoch 1 train 0.8473 test 0.5692 metric ['0.8537']
# 100%|██████████| 91/91 [00:46<00:00,  1.94it/s]
# 2025-02-16 16:49:52.535 | INFO     | mltrainer.trainer:report:191 - Epoch 2 train 0.6380 test 0.4464 metric ['0.8722']
# 100%|██████████| 91/91 [00:49<00:00,  1.84it/s]
# 2025-02-16 16:50:53.214 | INFO     | mltrainer.trainer:report:191 - Epoch 3 train 0.5651 test 0.3956 metric ['0.8722']
# 100%|██████████| 91/91 [00:47<00:00,  1.92it/s]
# 2025-02-16 16:51:50.201 | INFO     | mltrainer.trainer:report:191 - Epoch 4 train 0.5053 test 0.3551 metric ['0.8864']
# 100%|██████████| 91/91 [00:45<00:00,  2.00it/s]
# 2025-02-16 16:52:45.111 | INFO     | mltrainer.trainer:report:191 - Epoch 5 train 0.4488 test 0.3363 metric ['0.9006']
# 100%|██████████| 91/91 [00:34<00:00,  2.65it/s]
# 2025-02-16 16:53:26.910 | INFO     | mltrainer.trainer:report:191 - Epoch 6 train 0.4400 test 0.3245 metric ['0.8906']
# 100%|██████████| 91/91 [00:34<00:00,  2.65it/s]
# 2025-02-16 16:54:08.834 | INFO     | mltrainer.trainer:report:191 - Epoch 7 train 0.4410 test 0.3194 metric ['0.8977']
# 100%|██████████| 91/91 [00:34<00:00,  2.62it/s]
# 2025-02-16 16:54:50.971 | INFO     | mltrainer.trainer:report:191 - Epoch 8 train 0.4115 test 0.3042 metric ['0.9006']
# 100%|██████████| 91/91 [00:35<00:00,  2.60it/s]
# 2025-02-16 16:55:33.343 | INFO     | mltrainer.trainer:report:191 - Epoch 9 train 0.4315 test 0.3039 metric ['0.8991']
# 100%|██████████| 91/91 [00:34<00:00,  2.61it/s]
# 2025-02-16 16:56:15.642 | INFO     | mltrainer.trainer:report:191 - Epoch 10 train 0.3861 test 0.2918 metric ['0.9062']
# 100%|██████████| 91/91 [00:34<00:00,  2.66it/s]
# 2025-02-16 16:56:57.417 | INFO     | mltrainer.trainer:report:191 - Epoch 11 train 0.3927 test 0.3072 metric ['0.9105']
# 100%|██████████| 91/91 [00:35<00:00,  2.59it/s]
# 2025-02-16 16:57:39.922 | INFO     | mltrainer.trainer:report:191 - Epoch 12 train 0.3714 test 0.2928 metric ['0.9105']
# 100%|██████████| 91/91 [00:35<00:00,  2.57it/s]
# 2025-02-16 16:58:22.871 | INFO     | mltrainer.trainer:report:191 - Epoch 13 train 0.4024 test 0.2929 metric ['0.9119']
# 100%|██████████| 91/91 [00:34<00:00,  2.64it/s]
# 2025-02-16 16:59:04.774 | INFO     | mltrainer.trainer:report:191 - Epoch 14 train 0.3956 test 0.2883 metric ['0.9134']
# 100%|██████████| 91/91 [00:35<00:00,  2.58it/s]
# 2025-02-16 16:59:47.400 | INFO     | mltrainer.trainer:report:191 - Epoch 15 train 0.3783 test 0.2897 metric ['0.9119']
# 100%|██████████| 91/91 [00:34<00:00,  2.64it/s]
# 2025-02-16 17:00:29.285 | INFO     | mltrainer.trainer:report:191 - Epoch 16 train 0.3845 test 0.2919 metric ['0.9091']
# 100%|██████████| 91/91 [00:34<00:00,  2.60it/s]
# 2025-02-16 17:01:11.711 | INFO     | mltrainer.trainer:report:191 - Epoch 17 train 0.3825 test 0.2891 metric ['0.9148']
# 100%|██████████| 91/91 [00:34<00:00,  2.62it/s]
# 2025-02-16 17:01:53.952 | INFO     | mltrainer.trainer:report:191 - Epoch 18 train 0.3835 test 0.2933 metric ['0.9119']
# 100%|██████████| 91/91 [00:34<00:00,  2.62it/s]
# 2025-02-16 17:02:36.321 | INFO     | mltrainer.trainer:report:191 - Epoch 19 train 0.3741 test 0.2942 metric ['0.9105']
# 100%|██████████| 91/91 [00:34<00:00,  2.63it/s]
# 2025-02-16 17:03:18.407 | INFO     | mltrainer.trainer:report:191 - Epoch 20 train 0.3622 test 0.2868 metric ['0.9134']
# 100%|██████████| 91/91 [00:34<00:00,  2.60it/s]
# 2025-02-16 17:04:00.918 | INFO     | mltrainer.trainer:report:191 - Epoch 21 train 0.3768 test 0.2904 metric ['0.9176']
# 100%|██████████| 91/91 [00:35<00:00,  2.57it/s]
# 2025-02-16 17:04:43.882 | INFO     | mltrainer.trainer:report:191 - Epoch 22 train 0.3729 test 0.2922 metric ['0.9162']
# 100%|██████████| 91/91 [00:34<00:00,  2.62it/s]
# 2025-02-16 17:05:26.240 | INFO     | mltrainer.trainer:report:191 - Epoch 23 train 0.3740 test 0.2970 metric ['0.9105']
# 100%|██████████| 91/91 [00:34<00:00,  2.63it/s]
# 2025-02-16 17:06:08.330 | INFO     | mltrainer.trainer:report:191 - Epoch 24 train 0.4013 test 0.2907 metric ['0.9134']
# 100%|██████████| 91/91 [00:35<00:00,  2.59it/s]
# 2025-02-16 17:06:50.911 | INFO     | mltrainer.trainer:report:191 - Epoch 25 train 0.3824 test 0.2904 metric ['0.9077']
# 100%|██████████| 91/91 [00:34<00:00,  2.61it/s]
# 2025-02-16 17:07:33.282 | INFO     | mltrainer.trainer:report:191 - Epoch 26 train 0.3972 test 0.2933 metric ['0.9105']
# 100%|██████████| 91/91 [00:34<00:00,  2.65it/s]
# 2025-02-16 17:08:15.486 | INFO     | mltrainer.trainer:report:191 - Epoch 27 train 0.3795 test 0.2959 metric ['0.9119']
# 100%|██████████| 91/91 [00:34<00:00,  2.61it/s]
# 2025-02-16 17:08:57.995 | INFO     | mltrainer.trainer:report:191 - Epoch 28 train 0.3920 test 0.2967 metric ['0.9091']
# 100%|██████████| 91/91 [00:35<00:00,  2.59it/s]
# 2025-02-16 17:09:40.581 | INFO     | mltrainer.trainer:report:191 - Epoch 29 train 0.3928 test 0.2855 metric ['0.9148']
# 100%|██████████| 30/30 [22:37<00:00, 45.25s/it]

# %% [markdown]
# <font color='green'>
#
# **Even after adding a Linear layer, the overall accuracy is not improved significantly. This implies that it is possible that we might have maxed the performance for current configuration of our model. Hence, increasing number of layers might not help to improve the results. We might have to inspect the data augmentation technique, it is possible that we might have some oppurtunity to improve the overall performance by adjusting the data augmentation protocol.**
# </font>
