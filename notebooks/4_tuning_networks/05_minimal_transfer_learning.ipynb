# %% [markdown]
# <td>
# <a href="https://colab.research.google.com/github/raoulg/MADS-MachineLearning-course/blob/master/notebooks/4_tuning_networks/05_minimal_transfer_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# </td>

# %%
# For tips on running notebooks in Google Colab, see
# https://pytorch.org/tutorials/beginner/colab
# %matplotlib inline

# %% [markdown]
# This tutorial is based on the PyTorch tutorial for transfer learning. The original tutorial can be found [here](https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html).
#
# Transfer learning utilizes the idea that a model trained on a large dataset can be used as a starting point for a model trained on a smaller dataset. This is especially useful when the smaller dataset is not large enough to train a model from scratch. In this tutorial, we will use a pre-trained model to classify ants and bees. The dataset contains 120 training images and 75 validation images for each class.
#
# The two major transfer learning scenarios look as follows:
#
# -   **Finetuning the ConvNet**: Instead of random initialization, we
#     initialize the network with a pretrained network, like the one that
#     is trained on imagenet 1000 dataset. Rest of the training looks as
#     usual.
# -   **ConvNet as fixed feature extractor**: Here, we will freeze the
#     weights for all of the network except that of the final fully
#     connected layer. This last fully connected layer is replaced with a
#     new one with random weights and only this layer is trained.

# %%
import os

# Check if the notebook is running on Google Colab
if 'COLAB_GPU' in os.environ:
    # Running on Google Colab; install loguru
    # !pip install loguru
else:
    # Not running on Google Colab; you might be on a local setup
    print("Not running on Google Colab. Make sure you have hardware accelaration available.")

from pathlib import Path
import requests
import zipfile
from loguru import logger
# Out:
# Not running on Google Colab. Make sure you have hardware accelaration available.

# %% [markdown]
# Let's download a small dataset.

# %% [markdown]
# <font color='green'>
#
# **Code modified** to seperately check for both folders, because sometimes parent folder is presnet but the dataset is not present.
# </font>

# %%
def get_hymenoptera():
    datadir = Path.home() / ".cache/mads_datasets"
    url = "https://download.pytorch.org/tutorial/hymenoptera_data.zip"

    # Edit: seperatly check for both folders
    if not datadir.exists():
        logger.info(f"Creating directory {datadir}")
        datadir.mkdir(parents=True)

    # Edit: seperatly check for both folders
    if not Path(os.path.join(datadir, "hymenoptera_data")).exists():
        response = requests.get(url)
        zip_file_path = datadir / "hymenoptera_data.zip"
        with open(zip_file_path, "wb") as f:
            f.write(response.content)

        logger.info(f"Extracting {zip_file_path}")
        with zipfile.ZipFile(zip_file_path, "r") as zip_ref:
            zip_ref.extractall(datadir)
        zip_file_path.unlink()
    else:
        logger.info(f"Directory {datadir / 'hymenoptera_data'} already exists, skipping download.")
    return datadir / "hymenoptera_data"

datadir = get_hymenoptera()
# Out:
# 2025-02-16 11:12:55.417 | INFO     | __main__:get_hymenoptera:22 - Directory /home/sarmad/.cache/mads_datasets/hymenoptera_data already exists, skipping download.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory

cudnn.benchmark = True
plt.ion()   # interactive mode

# %% [markdown]
# Load Data
# =========
#
# We will use torchvision and torch.utils.data packages for loading the
# data.
#
# The problem we\'re going to solve is training a model to classify
# **ants** and **bees**. We have about 120 training images each for ants
# and bees.
#
# There are 75 validation images for each class. Usually, this
# is too small of a dataset to generalize upon, if trained from scratch.
# Since we are using transfer learning, we should be able to generalize
# reasonably well.
#
# This dataset is a very small subset of imagenet.

# %%
def create_dataloaders():
    data_transforms = {
        'train': transforms.Compose([
            transforms.RandomResizedCrop(224),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
        'val': transforms.Compose([
            transforms.Resize(256),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
    }

    image_datasets = {x: datasets.ImageFolder(datadir / x, data_transforms[x]) for x in ['train', 'val']}
    dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                                shuffle=True, num_workers=4)
                for x in ['train', 'val']}
    dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
    class_names = image_datasets['train'].classes
    return dataloaders, dataset_sizes, class_names

dataloaders, dataset_sizes, class_names = create_dataloaders()

# %%
if torch.backends.mps.is_available() and torch.backends.mps.is_built():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = "cpu"
    logger.warning("This model will take 15-20 minutes on CPU. Consider using accelaration, eg with google colab (see button on top of the page)")

# in my system cuda is not working so using device=cpu
logger.info(f"Using {device}")
# Out:
# 2025-02-16 11:12:58.157 | INFO     | __main__:<module>:10 - Using cuda

# %% [markdown]
# <font color='green'>
#
# **Code added**
# </font>

# %%
# in my system cuda is not working so using device=cpu
device = 'cpu'
logger.info(f"Using {device}")
# Out:
# 2025-02-16 11:12:58.171 | INFO     | __main__:<module>:3 - Using cpu

# %% [markdown]
# Visualize a few images
# ======================
#
# Let\'s visualize a few training images so as to understand the data
# augmentations.

# %%
def imshow(img, title):
    img = img.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    img = std * img + mean
    img = np.clip(img, 0, 1)
    plt.imshow(img)
    plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
img = torchvision.utils.make_grid(inputs)

imshow(img, title=[class_names[x] for x in classes])

# %% [markdown]
# # Training the model

# %% [markdown]
# Up to this point, we have been using the mltrainer module.
# However, to both make it easer to run this on google colab and to show you the full code of a training loop, I will define the functions for training and evaluating the model here.

# %%
def train(model, dataloader, lossfn, optimizer, device):
    model.train()
    train_loss: float = 0.0
    train_acc: float = 0.0
    for x, y in dataloader:
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad()
        yhat = model(x)
        loss = lossfn(yhat, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, acc = torch.max(yhat, 1)
        train_acc += torch.sum(acc == y.data)
    return train_loss, train_acc

# %%
def test(model, dataloader, lossfn, optimizer, scheduler, device):
    model.eval()
    test_loss: float = 0.0
    test_acc: float = 0.0
    for x, y in dataloader:
        x = x.to(device)
        y = y.to(device)
        yhat = model(x)
        loss = lossfn(yhat, y)
        test_loss += loss.item()
        _, acc = torch.max(yhat, 1)
        test_acc += torch.sum(acc == y.data)
    scheduler.step(test_loss)
    return test_loss, test_acc

# %%
def train_model(model, lossfn, optimizer, scheduler, num_epochs, dataloaders, dataset_sizes, device):
    with TemporaryDirectory() as tempdir:
        best_model_params_path = Path(tempdir) / 'best_model_params.pt'
        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0 # we will only save the best model

        for epoch in range(num_epochs):
            logger.info(f'Epoch {epoch}/{num_epochs - 1}')
            train_loss, train_acc = train(model, dataloaders['train'], lossfn, optimizer, device)
            train_loss = train_loss / dataset_sizes['train']
            train_acc = train_acc / dataset_sizes['train']
            logger.info(f'Train Loss: {train_loss:.4f} Accuracy: {train_acc:.4f}')
            test_loss, test_acc = test(model, dataloaders['val'], lossfn, optimizer, scheduler, device)
            test_loss = test_loss / dataset_sizes['val']
            test_acc = test_acc / dataset_sizes['val']
            logger.info(f'Test Loss: {test_loss:.4f} Accuracy: {test_acc:.4f}')
            if test_acc > best_acc:
                    best_acc = test_acc
                    logger.info(f"New best accuracy: {best_acc:.4f}, saving model")
                    torch.save(model.state_dict(), best_model_params_path)
        model.load_state_dict(torch.load(best_model_params_path))
        return model

# %% [markdown]
# Visualizing the model predictions
# =================================
#
# Generic function to display predictions for a few images

# %%
def visualize_model(model, num_images=6):
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                title = class_names[preds[j]]
                ax.set_title(f'predicted: {title}')
                imshow(inputs.cpu().data[j], title)

                if images_so_far == num_images:
                    return

# %% [markdown]
# Finetuning the ConvNet
# ======================
#
# Load a pretrained model and reset final fully connected layer.
#
# <font color='green'>
#
# The following code will finetune the whole resnet network. Generally, it is not desireable to finetune whole network, if the pretrained weights are for the same domain task. For example, if the the pretrained weights are for classification task and you are also training for classification task, then it is advised to `freeze` the initial pretrained layers to speedup the finetunnig process, and it also provide better final accuracy.
#
# However, lets confirm this theory by performing experiements. First, we finetune the whole network to inspect the performance. Afterwards, we perform fintunning on few layers by freezing most of the layers to retain the pretrained weights.
# </font>

# %% [markdown]
# <font color='green'>
#
# **1. Fintunnig whole network**
# </font>

# %%
model = models.resnet18(weights='IMAGENET1K_V1')
num_ftrs = model.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to ``nn.Linear(num_ftrs, len(class_names))``.
model.fc = nn.Linear(num_ftrs, 2)

model = model.to(device)
lossfn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# Decay LR by a factor of 0.1 every 7 epochs
settings = {'step_size' : 7, 'gamma' : 0.1}
scheduler = lr_scheduler.StepLR(optimizer, **settings)

# %%
model = train_model(model, lossfn, optimizer, scheduler, 25, dataloaders, dataset_sizes, device)
# Out:
# 2025-02-16 11:12:58.996 | INFO     | __main__:train_model:8 - Epoch 0/24
# 2025-02-16 11:13:24.503 | INFO     | __main__:train_model:12 - Train Loss: 0.1381 Accuracy: 0.7459
# /home/sarmad/anaconda3/envs/conda_kernel/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:156: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# 2025-02-16 11:13:30.270 | INFO     | __main__:train_model:16 - Test Loss: 0.0692 Accuracy: 0.8824
# 2025-02-16 11:13:30.271 | INFO     | __main__:train_model:19 - New best accuracy: 0.8824, saving model
# 2025-02-16 11:13:30.335 | INFO     | __main__:train_model:8 - Epoch 1/24
# 2025-02-16 11:13:53.328 | INFO     | __main__:train_model:12 - Train Loss: 0.0963 Accuracy: 0.8074
# 2025-02-16 11:13:58.029 | INFO     | __main__:train_model:16 - Test Loss: 0.0480 Accuracy: 0.9412
# 2025-02-16 11:13:58.030 | INFO     | __main__:train_model:19 - New best accuracy: 0.9412, saving model
# 2025-02-16 11:13:58.112 | INFO     | __main__:train_model:8 - Epoch 2/24
# 2025-02-16 11:14:18.984 | INFO     | __main__:train_model:12 - Train Loss: 0.0978 Accuracy: 0.8402
# 2025-02-16 11:14:24.094 | INFO     | __main__:train_model:16 - Test Loss: 0.0402 Accuracy: 0.9608
# 2025-02-16 11:14:24.095 | INFO     | __main__:train_model:19 - New best accuracy: 0.9608, saving model
# 2025-02-16 11:14:24.183 | INFO     | __main__:train_model:8 - Epoch 3/24
# 2025-02-16 11:14:42.242 | INFO     | __main__:train_model:12 - Train Loss: 0.1121 Accuracy: 0.7951
# 2025-02-16 11:14:45.860 | INFO     | __main__:train_model:16 - Test Loss: 0.0530 Accuracy: 0.9281
# 2025-02-16 11:14:45.860 | INFO     | __main__:train_model:8 - Epoch 4/24
# 2025-02-16 11:15:02.597 | INFO     | __main__:train_model:12 - Train Loss: 0.1073 Accuracy: 0.8238
# 2025-02-16 11:15:06.309 | INFO     | __main__:train_model:16 - Test Loss: 0.0420 Accuracy: 0.9542
# 2025-02-16 11:15:06.310 | INFO     | __main__:train_model:8 - Epoch 5/24
# 2025-02-16 11:15:22.482 | INFO     | __main__:train_model:12 - Train Loss: 0.1839 Accuracy: 0.7336
# 2025-02-16 11:15:26.054 | INFO     | __main__:train_model:16 - Test Loss: 0.0732 Accuracy: 0.9216
# 2025-02-16 11:15:26.055 | INFO     | __main__:train_model:8 - Epoch 6/24
# 2025-02-16 11:15:43.564 | INFO     | __main__:train_model:12 - Train Loss: 0.0882 Accuracy: 0.8402
# 2025-02-16 11:15:47.331 | INFO     | __main__:train_model:16 - Test Loss: 0.0532 Accuracy: 0.9150
# 2025-02-16 11:15:47.331 | INFO     | __main__:train_model:8 - Epoch 7/24
# 2025-02-16 11:16:03.637 | INFO     | __main__:train_model:12 - Train Loss: 0.0841 Accuracy: 0.8648
# 2025-02-16 11:16:07.235 | INFO     | __main__:train_model:16 - Test Loss: 0.0599 Accuracy: 0.9216
# 2025-02-16 11:16:07.236 | INFO     | __main__:train_model:8 - Epoch 8/24
# 2025-02-16 11:16:23.300 | INFO     | __main__:train_model:12 - Train Loss: 0.0862 Accuracy: 0.8689
# 2025-02-16 11:16:26.892 | INFO     | __main__:train_model:16 - Test Loss: 0.0483 Accuracy: 0.9477
# 2025-02-16 11:16:26.893 | INFO     | __main__:train_model:8 - Epoch 9/24
# 2025-02-16 11:16:43.116 | INFO     | __main__:train_model:12 - Train Loss: 0.0779 Accuracy: 0.8566
# 2025-02-16 11:16:46.981 | INFO     | __main__:train_model:16 - Test Loss: 0.0569 Accuracy: 0.9281
# 2025-02-16 11:16:46.982 | INFO     | __main__:train_model:8 - Epoch 10/24
# 2025-02-16 11:17:02.989 | INFO     | __main__:train_model:12 - Train Loss: 0.1069 Accuracy: 0.8074
# 2025-02-16 11:17:06.684 | INFO     | __main__:train_model:16 - Test Loss: 0.0498 Accuracy: 0.9412
# 2025-02-16 11:17:06.685 | INFO     | __main__:train_model:8 - Epoch 11/24
# 2025-02-16 11:17:23.803 | INFO     | __main__:train_model:12 - Train Loss: 0.0709 Accuracy: 0.8934
# 2025-02-16 11:17:27.380 | INFO     | __main__:train_model:16 - Test Loss: 0.0414 Accuracy: 0.9412
# 2025-02-16 11:17:27.381 | INFO     | __main__:train_model:8 - Epoch 12/24
# 2025-02-16 11:17:43.507 | INFO     | __main__:train_model:12 - Train Loss: 0.1091 Accuracy: 0.8320
# 2025-02-16 11:17:47.311 | INFO     | __main__:train_model:16 - Test Loss: 0.0809 Accuracy: 0.8758
# 2025-02-16 11:17:47.312 | INFO     | __main__:train_model:8 - Epoch 13/24
# 2025-02-16 11:18:03.584 | INFO     | __main__:train_model:12 - Train Loss: 0.1147 Accuracy: 0.8197
# 2025-02-16 11:18:07.330 | INFO     | __main__:train_model:16 - Test Loss: 0.0577 Accuracy: 0.9216
# 2025-02-16 11:18:07.331 | INFO     | __main__:train_model:8 - Epoch 14/24
# 2025-02-16 11:18:24.372 | INFO     | __main__:train_model:12 - Train Loss: 0.0510 Accuracy: 0.9098
# 2025-02-16 11:18:28.083 | INFO     | __main__:train_model:16 - Test Loss: 0.0573 Accuracy: 0.9150
# 2025-02-16 11:18:28.085 | INFO     | __main__:train_model:8 - Epoch 15/24
# 2025-02-16 11:18:44.290 | INFO     | __main__:train_model:12 - Train Loss: 0.0608 Accuracy: 0.8975
# 2025-02-16 11:18:48.017 | INFO     | __main__:train_model:16 - Test Loss: 0.0521 Accuracy: 0.9281
# 2025-02-16 11:18:48.018 | INFO     | __main__:train_model:8 - Epoch 16/24
# 2025-02-16 11:19:04.226 | INFO     | __main__:train_model:12 - Train Loss: 0.0486 Accuracy: 0.9180
# 2025-02-16 11:19:08.051 | INFO     | __main__:train_model:16 - Test Loss: 0.0500 Accuracy: 0.9346
# 2025-02-16 11:19:08.051 | INFO     | __main__:train_model:8 - Epoch 17/24
# 2025-02-16 11:19:24.803 | INFO     | __main__:train_model:12 - Train Loss: 0.1079 Accuracy: 0.8320
# 2025-02-16 11:19:28.621 | INFO     | __main__:train_model:16 - Test Loss: 0.0546 Accuracy: 0.9216
# 2025-02-16 11:19:28.622 | INFO     | __main__:train_model:8 - Epoch 18/24
# 2025-02-16 11:19:45.312 | INFO     | __main__:train_model:12 - Train Loss: 0.0834 Accuracy: 0.8402
# 2025-02-16 11:19:48.897 | INFO     | __main__:train_model:16 - Test Loss: 0.0524 Accuracy: 0.9281
# 2025-02-16 11:19:48.898 | INFO     | __main__:train_model:8 - Epoch 19/24
# 2025-02-16 11:20:03.984 | INFO     | __main__:train_model:12 - Train Loss: 0.0738 Accuracy: 0.8893
# 2025-02-16 11:20:07.640 | INFO     | __main__:train_model:16 - Test Loss: 0.0490 Accuracy: 0.9346
# 2025-02-16 11:20:07.641 | INFO     | __main__:train_model:8 - Epoch 20/24
# 2025-02-16 11:20:22.649 | INFO     | __main__:train_model:12 - Train Loss: 0.0743 Accuracy: 0.8730
# 2025-02-16 11:20:26.110 | INFO     | __main__:train_model:16 - Test Loss: 0.0476 Accuracy: 0.9346
# 2025-02-16 11:20:26.110 | INFO     | __main__:train_model:8 - Epoch 21/24
# 2025-02-16 11:20:40.984 | INFO     | __main__:train_model:12 - Train Loss: 0.0709 Accuracy: 0.8689
# 2025-02-16 11:20:44.858 | INFO     | __main__:train_model:16 - Test Loss: 0.0471 Accuracy: 0.9346
# 2025-02-16 11:20:44.859 | INFO     | __main__:train_model:8 - Epoch 22/24
# 2025-02-16 11:20:59.829 | INFO     | __main__:train_model:12 - Train Loss: 0.0602 Accuracy: 0.8934
# 2025-02-16 11:21:03.415 | INFO     | __main__:train_model:16 - Test Loss: 0.0447 Accuracy: 0.9477
# 2025-02-16 11:21:03.415 | INFO     | __main__:train_model:8 - Epoch 23/24
# 2025-02-16 11:21:18.259 | INFO     | __main__:train_model:12 - Train Loss: 0.1094 Accuracy: 0.8115
# 2025-02-16 11:21:21.984 | INFO     | __main__:train_model:16 - Test Loss: 0.1076 Accuracy: 0.8824
# 2025-02-16 11:21:21.984 | INFO     | __main__:train_model:8 - Epoch 24/24
# 2025-02-16 11:21:37.004 | INFO     | __main__:train_model:12 - Train Loss: 0.1151 Accuracy: 0.8484
# 2025-02-16 11:21:40.500 | INFO     | __main__:train_model:16 - Test Loss: 0.0819 Accuracy: 0.9150

# %% [markdown]
# Train and evaluate
# ==================
#
# It should take around 15-25 min on CPU. On GPU though, it takes less
# than a minute.

# %%
visualize_model(model)

# %% [markdown]
# ConvNet as fixed feature extractor
# ==================================
#
# Here, we need to freeze all the network except the final layer. We need
# to set `requires_grad = False` to freeze the parameters so that the
# gradients are not computed in `backward()`.
#
# This has some advantages over finetuning the complete model:
# - **Faster**: Since we are not computing most of the gradients, the
#     forward pass is faster.
# - **Memory Efficient**: The memory required for computing the gradients is
#     less.
# - **Less risk of overfitting**: Since most of the model is frozen, the
#     risk of overfitting on this small dataset is less.

# %% [markdown]
# <font color='green'>
#
# **2. Finetuning on few layers**
#
# code modified
# </font>

# %%
model_conv = torchvision.models.resnet18(weights='IMAGENET1K_V1')

# Freeze the early layers to retain the pretrained weights
# this will help model to learn faster and acheive higher accuracy
for param in model_conv.parameters():
    param.requires_grad = False

# Parameters of newly constructed modules have requires_grad=True by default
num_ftrs = model_conv.fc.in_features
model_conv.fc = nn.Linear(num_ftrs, 2)

model_conv = model_conv.to(device)

lossfn = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
optimizer = optim.SGD(model_conv.fc.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# %% [markdown]
# Train and evaluate
# ==================
#
# On CPU this will take about half the time compared to previous scenario.
# This is expected as gradients don\'t need to be computed for most of the
# network. However, forward does need to be computed.

# %%
model_conv = train_model(model_conv, lossfn, optimizer, scheduler, 25, dataloaders, dataset_sizes, device)
# Out:
# 2025-02-16 11:21:41.478 | INFO     | __main__:train_model:8 - Epoch 0/24
# 2025-02-16 11:21:47.199 | INFO     | __main__:train_model:12 - Train Loss: 0.1773 Accuracy: 0.6393
# 2025-02-16 11:21:50.691 | INFO     | __main__:train_model:16 - Test Loss: 0.0629 Accuracy: 0.9085
# 2025-02-16 11:21:50.692 | INFO     | __main__:train_model:19 - New best accuracy: 0.9085, saving model
# 2025-02-16 11:21:50.770 | INFO     | __main__:train_model:8 - Epoch 1/24
# 2025-02-16 11:21:56.379 | INFO     | __main__:train_model:12 - Train Loss: 0.0985 Accuracy: 0.8238
# 2025-02-16 11:21:59.729 | INFO     | __main__:train_model:16 - Test Loss: 0.0610 Accuracy: 0.9150
# 2025-02-16 11:21:59.729 | INFO     | __main__:train_model:19 - New best accuracy: 0.9150, saving model
# 2025-02-16 11:21:59.790 | INFO     | __main__:train_model:8 - Epoch 2/24
# 2025-02-16 11:22:05.395 | INFO     | __main__:train_model:12 - Train Loss: 0.0975 Accuracy: 0.8443
# 2025-02-16 11:22:08.756 | INFO     | __main__:train_model:16 - Test Loss: 0.0590 Accuracy: 0.9216
# 2025-02-16 11:22:08.756 | INFO     | __main__:train_model:19 - New best accuracy: 0.9216, saving model
# 2025-02-16 11:22:08.804 | INFO     | __main__:train_model:8 - Epoch 3/24
# 2025-02-16 11:22:15.804 | INFO     | __main__:train_model:12 - Train Loss: 0.1093 Accuracy: 0.8033
# 2025-02-16 11:22:19.503 | INFO     | __main__:train_model:16 - Test Loss: 0.0593 Accuracy: 0.9150
# 2025-02-16 11:22:19.505 | INFO     | __main__:train_model:8 - Epoch 4/24
# 2025-02-16 11:22:25.248 | INFO     | __main__:train_model:12 - Train Loss: 0.1020 Accuracy: 0.8074
# 2025-02-16 11:22:28.657 | INFO     | __main__:train_model:16 - Test Loss: 0.0571 Accuracy: 0.9150
# 2025-02-16 11:22:28.658 | INFO     | __main__:train_model:8 - Epoch 5/24
# 2025-02-16 11:22:34.318 | INFO     | __main__:train_model:12 - Train Loss: 0.0925 Accuracy: 0.8443
# 2025-02-16 11:22:37.716 | INFO     | __main__:train_model:16 - Test Loss: 0.0565 Accuracy: 0.9150
# 2025-02-16 11:22:37.716 | INFO     | __main__:train_model:8 - Epoch 6/24
# 2025-02-16 11:22:43.313 | INFO     | __main__:train_model:12 - Train Loss: 0.0908 Accuracy: 0.8566
# 2025-02-16 11:22:46.957 | INFO     | __main__:train_model:16 - Test Loss: 0.0556 Accuracy: 0.9150
# 2025-02-16 11:22:46.957 | INFO     | __main__:train_model:8 - Epoch 7/24
# 2025-02-16 11:22:52.718 | INFO     | __main__:train_model:12 - Train Loss: 0.1133 Accuracy: 0.7746
# 2025-02-16 11:22:56.161 | INFO     | __main__:train_model:16 - Test Loss: 0.0558 Accuracy: 0.9150
# 2025-02-16 11:22:56.162 | INFO     | __main__:train_model:8 - Epoch 8/24
# 2025-02-16 11:23:02.017 | INFO     | __main__:train_model:12 - Train Loss: 0.0944 Accuracy: 0.8156
# 2025-02-16 11:23:05.369 | INFO     | __main__:train_model:16 - Test Loss: 0.0566 Accuracy: 0.9150
# 2025-02-16 11:23:05.369 | INFO     | __main__:train_model:8 - Epoch 9/24
# 2025-02-16 11:23:11.991 | INFO     | __main__:train_model:12 - Train Loss: 0.0944 Accuracy: 0.8361
# 2025-02-16 11:23:15.487 | INFO     | __main__:train_model:16 - Test Loss: 0.0544 Accuracy: 0.9281
# 2025-02-16 11:23:15.488 | INFO     | __main__:train_model:19 - New best accuracy: 0.9281, saving model
# 2025-02-16 11:23:15.547 | INFO     | __main__:train_model:8 - Epoch 10/24
# 2025-02-16 11:23:20.971 | INFO     | __main__:train_model:12 - Train Loss: 0.0967 Accuracy: 0.8361
# 2025-02-16 11:23:24.599 | INFO     | __main__:train_model:16 - Test Loss: 0.0617 Accuracy: 0.9020
# 2025-02-16 11:23:24.601 | INFO     | __main__:train_model:8 - Epoch 11/24
# 2025-02-16 11:23:30.146 | INFO     | __main__:train_model:12 - Train Loss: 0.0814 Accuracy: 0.8730
# 2025-02-16 11:23:33.592 | INFO     | __main__:train_model:16 - Test Loss: 0.0529 Accuracy: 0.9150
# 2025-02-16 11:23:33.592 | INFO     | __main__:train_model:8 - Epoch 12/24
# 2025-02-16 11:23:39.396 | INFO     | __main__:train_model:12 - Train Loss: 0.0951 Accuracy: 0.8156
# 2025-02-16 11:23:42.844 | INFO     | __main__:train_model:16 - Test Loss: 0.0540 Accuracy: 0.9216
# 2025-02-16 11:23:42.845 | INFO     | __main__:train_model:8 - Epoch 13/24
# 2025-02-16 11:23:48.300 | INFO     | __main__:train_model:12 - Train Loss: 0.0870 Accuracy: 0.8279
# 2025-02-16 11:23:51.862 | INFO     | __main__:train_model:16 - Test Loss: 0.0533 Accuracy: 0.9281
# 2025-02-16 11:23:51.863 | INFO     | __main__:train_model:8 - Epoch 14/24
# 2025-02-16 11:23:57.536 | INFO     | __main__:train_model:12 - Train Loss: 0.0964 Accuracy: 0.8320
# 2025-02-16 11:24:00.945 | INFO     | __main__:train_model:16 - Test Loss: 0.0483 Accuracy: 0.9346
# 2025-02-16 11:24:00.946 | INFO     | __main__:train_model:19 - New best accuracy: 0.9346, saving model
# 2025-02-16 11:24:00.998 | INFO     | __main__:train_model:8 - Epoch 15/24
# 2025-02-16 11:24:06.896 | INFO     | __main__:train_model:12 - Train Loss: 0.0938 Accuracy: 0.8443
# 2025-02-16 11:24:10.403 | INFO     | __main__:train_model:16 - Test Loss: 0.0479 Accuracy: 0.9346
# 2025-02-16 11:24:10.404 | INFO     | __main__:train_model:8 - Epoch 16/24
# 2025-02-16 11:24:15.865 | INFO     | __main__:train_model:12 - Train Loss: 0.0829 Accuracy: 0.8484
# 2025-02-16 11:24:19.189 | INFO     | __main__:train_model:16 - Test Loss: 0.0491 Accuracy: 0.9346
# 2025-02-16 11:24:19.190 | INFO     | __main__:train_model:8 - Epoch 17/24
# 2025-02-16 11:24:24.997 | INFO     | __main__:train_model:12 - Train Loss: 0.0845 Accuracy: 0.8484
# 2025-02-16 11:24:28.435 | INFO     | __main__:train_model:16 - Test Loss: 0.0488 Accuracy: 0.9281
# 2025-02-16 11:24:28.435 | INFO     | __main__:train_model:8 - Epoch 18/24
# 2025-02-16 11:24:34.009 | INFO     | __main__:train_model:12 - Train Loss: 0.0949 Accuracy: 0.8361
# 2025-02-16 11:24:37.700 | INFO     | __main__:train_model:16 - Test Loss: 0.0500 Accuracy: 0.9281
# 2025-02-16 11:24:37.701 | INFO     | __main__:train_model:8 - Epoch 19/24
# 2025-02-16 11:24:43.281 | INFO     | __main__:train_model:12 - Train Loss: 0.1040 Accuracy: 0.7787
# 2025-02-16 11:24:46.453 | INFO     | __main__:train_model:16 - Test Loss: 0.0582 Accuracy: 0.9150
# 2025-02-16 11:24:46.454 | INFO     | __main__:train_model:8 - Epoch 20/24
# 2025-02-16 11:24:51.789 | INFO     | __main__:train_model:12 - Train Loss: 0.0770 Accuracy: 0.8975
# 2025-02-16 11:24:55.324 | INFO     | __main__:train_model:16 - Test Loss: 0.0479 Accuracy: 0.9346
# 2025-02-16 11:24:55.326 | INFO     | __main__:train_model:8 - Epoch 21/24
# 2025-02-16 11:25:00.624 | INFO     | __main__:train_model:12 - Train Loss: 0.0733 Accuracy: 0.8852
# 2025-02-16 11:25:03.903 | INFO     | __main__:train_model:16 - Test Loss: 0.0545 Accuracy: 0.9412
# 2025-02-16 11:25:03.904 | INFO     | __main__:train_model:19 - New best accuracy: 0.9412, saving model
# 2025-02-16 11:25:03.961 | INFO     | __main__:train_model:8 - Epoch 22/24
# 2025-02-16 11:25:09.638 | INFO     | __main__:train_model:12 - Train Loss: 0.0892 Accuracy: 0.8484
# 2025-02-16 11:25:13.084 | INFO     | __main__:train_model:16 - Test Loss: 0.0490 Accuracy: 0.9412
# 2025-02-16 11:25:13.085 | INFO     | __main__:train_model:8 - Epoch 23/24
# 2025-02-16 11:25:18.696 | INFO     | __main__:train_model:12 - Train Loss: 0.0929 Accuracy: 0.8361
# 2025-02-16 11:25:22.084 | INFO     | __main__:train_model:16 - Test Loss: 0.0474 Accuracy: 0.9477
# 2025-02-16 11:25:22.085 | INFO     | __main__:train_model:19 - New best accuracy: 0.9477, saving model
# 2025-02-16 11:25:22.142 | INFO     | __main__:train_model:8 - Epoch 24/24
# 2025-02-16 11:25:27.868 | INFO     | __main__:train_model:12 - Train Loss: 0.0824 Accuracy: 0.8484
# 2025-02-16 11:25:31.186 | INFO     | __main__:train_model:16 - Test Loss: 0.0469 Accuracy: 0.9346

# %% [markdown]
# <font color='green'>
#
# **The results from both the experiemnts shows that `freezing` the early layers of the network acheives better overall performance. After 25 epochs, the second model acheives 93% final accuracy as compared to 91% accuracy for the first model.**
# </font>

# %%
visualize_model(model_conv)
